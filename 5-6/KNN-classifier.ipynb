# %% [markdown]
# # KNN-классификатор

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import preprocessing
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = pd.read_csv("dermatology.data")
dataset
# Out:
#      erythema  scaling  definite borders  itching  koebner phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 353         2        1                 1        0                   1
# 354         3        2                 1        0                   1
# 355         3        2                 2        2                   3
# 356         2        1                 3        1                   2
# 357         3        2                 2        0                   0
#
#      polygonal papules  follicular papules  oral mucosal involvement  \
# 0                    0                   0                         0
# 1                    0                   0                         0
# 2                    3                   0                         3
# 3                    0                   0                         0
# 4                    2                   0                         2
# ..                 ...                 ...                       ...
# 353                  0                   0                         0
# 354                  0                   0                         0
# 355                  2                   0                         2
# 356                  3                   0                         2
# 357                  0                   0                         0
#
#      knee and elbow involvement  scalp involvement  ...  munro microabcess  \
# 0                             1                  0  ...                  0
# 1                             1                  1  ...                  0
# 2                             0                  0  ...                  0
# 3                             3                  2  ...                  3
# 4                             0                  0  ...                  2
# ..                          ...                ...  ...                ...
# 353                           0                  0  ...                  0
# 354                           0                  0  ...                  1
# 355                           0                  0  ...                  0
# 356                           0                  0  ...                  0
# 357                           3                  3  ...                  2
#
#      focal hypergranulosis  disappearance of the granular layer  \
# 0                        0                                    3
# 1                        0                                    0
# 2                        2                                    3
# 3                        0                                    0
# 4                        3                                    2
# ..                     ...                                  ...
# 353                      0                                    1
# 354                      0                                    1
# 355                      3                                    0
# 356                      2                                    0
# 357                      0                                    0
#
#      vacuolisation and damage of basal layer  spongiosis  \
# 0                                          0           0
# 1                                          0           0
# 2                                          2           0
# 3                                          0           0
# 4                                          3           0
# ..                                       ...         ...
# 353                                        0           0
# 354                                        0           0
# 355                                        3           0
# 356                                        1           0
# 357                                        0           0
#
#      saw-tooth appearance of retes  follicular horn plug  \
# 0                                0                     1
# 1                                0                     1
# 2                                0                     2
# 3                                0                     3
# 4                                0                     2
# ..                             ...                   ...
# 353                              0                     2
# 354                              0                     2
# 355                              0                     2
# 356                              0                     2
# 357                              0                     3
#
#      perifollicular parakeratosis  inflammatory monoluclear inflitrate  \
# 0                               0                                   55
# 1                               0                                    8
# 2                               3                                   26
# 3                               0                                   40
# 4                               3                                   45
# ..                            ...                                  ...
# 353                             0                                   25
# 354                             0                                   36
# 355                             3                                   28
# 356                             3                                   50
# 357                             0                                   35
#
#      band-like infiltrate
# 0                       2
# 1                       1
# 2                       3
# 3                       1
# 4                       3
# ..                    ...
# 353                     4
# 354                     4
# 355                     3
# 356                     3
# 357                     1
#
# [358 rows x 35 columns]

# %%
#Выделяем признак, по которому будем классифицировать объекты
target_feature='spongiosis'
data = dataset.drop([target_feature], axis=1)
target = dataset[target_feature]

#Разделяем выборку на обучающую и тестовую
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.7)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
param_grid = {'n_neighbors': [1, 2, 3, 4, 5, 6, 7],
              'metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski'],
              'n_jobs': [1, 2, 3, 4, 5],
              'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']}
 
grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit = True)

# %%
grid.fit(X_train, y_train)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# {'algorithm': 'ball_tree', 'metric': 'chebyshev', 'n_jobs': 1, 'n_neighbors': 1}
# KNeighborsClassifier(algorithm='ball_tree', metric='chebyshev', n_jobs=1,
#                      n_neighbors=1)

# %%
print(target.unique())
# Out:
# [0 1 2 3]

# %%
knn = KNeighborsClassifier(algorithm='ball_tree', metric='chebyshev', n_jobs=1, n_neighbors=1)
knn.fit(X_train, y_train)

pred = knn.predict(X_test)
print("Общая точность: ", metrics.accuracy_score(y_test, y_pred=pred))
print("Precision: ", metrics.precision_score(y_test, y_pred=pred, average='weighted'))
print("Recall: ", metrics.recall_score(y_test, y_pred=pred, average='weighted'))
print("F1-measure: ", metrics.f1_score(y_test, y_pred=pred, average='weighted'))
#print(metrics.classification_report(y_test, y_pred=pred))
# Out:
# Общая точность:  0.9402390438247012
# Precision:  0.9546472408830506
# Recall:  0.9402390438247012
# F1-measure:  0.9470744879111413

# %%
import umap
reducer = umap.UMAP()
#Уменьшаем размерность данных и опорных векторов
X_test_2d = pd.DataFrame(reducer.fit_transform(X_test))

import matplotlib.pyplot as plt
colormap = np.array(['b', 'g', 'r', 'y'])

plt.title(target_feature)
plt.scatter(X_test_2d[0], X_test_2d[1], alpha=0.1, c=colormap[pred], cmap='viridis')

plt.show()

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=0)

X_test_2d = pd.DataFrame(tsne.fit_transform(X_test))

import matplotlib.pyplot as plt
colormap = np.array(['b', 'g', 'r', 'y'])

plt.title(target_feature)
plt.scatter(X_test_2d[0], X_test_2d[1], alpha=0.2, c=colormap[pred], cmap='viridis')

plt.show()

# %% [markdown]
# ## Сравнение разбиения на классы на основе выборок с известными метками классов метками выставленными классификатором

# %%
_, (ax1, ax2) = plt.subplots(1, 2)

X_test_2d = pd.DataFrame(tsne.fit_transform(X_test))

ax1.scatter(X_test_2d[0], X_test_2d[1], c=colormap[y_test], alpha=0.1)
ax1.set_title('Тестовые данные')
ax2.scatter(X_test_2d[0], X_test_2d[1], c=colormap[pred], alpha=0.1)
ax2.set_title('Предсказанные данные')
plt.show()
# Out:
# Text(0.5, 1.0, 'Предсказанные данные')
